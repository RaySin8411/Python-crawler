# %%
# %run stock.py

# %%
stock = Stock('2330', '2454', '2369')  # 建立Stock物件
stock.daily("2019", "7")  # 動態爬取指定的年月份中，股票代碼的每日收盤價
# Out:
#      0          1       2          3       4          5       6          7   \
# 0  2330  108/07/01  248.50  108/07/02  249.00  108/07/03  242.50  108/07/04
# 1  2454  108/07/01  314.00  108/07/02  319.00  108/07/03  317.50  108/07/04
# 2  2369  108/07/01    8.36  108/07/02    8.39  108/07/03    8.45  108/07/04
#
#        8          9   ...         39      40         41      42         43  \
# 0  244.00  108/07/05  ...  108/07/26  261.00  108/07/29  261.00  108/07/30
# 1  319.00  108/07/05  ...  108/07/26  313.50  108/07/29  319.00  108/07/30
# 2    8.46  108/07/05  ...  108/07/26    9.11  108/07/29    9.19  108/07/30
#
#        44         45      46      47      48
# 0  260.00  108/07/31  259.50  月平均收盤價  253.65
# 1  325.50  108/07/31  314.50  月平均收盤價  314.70
# 2    8.98  108/07/31    8.91  月平均收盤價    8.70
#
# [3 rows x 49 columns]

# %%
# %run stock_pd.py

# %%
listDji = ['2330', '2454', '2369']
for i in range(len(listDji)):
    result = create_df('20180701', listDji[i])
    print('股票代號 : %s' %listDji[i])
    print(result)
    print("----------------------------------------------")
# Out:
# 股票代號 : 2330
#                  成交股數         成交金額    開盤價    最高價    最低價    收盤價  漲跌價差   成交筆數  \
# 2018-07-02   33496442   7257081470  218.5  219.0  214.0  214.0  -2.5   8508
# 2018-07-03   28663220   6173115899  215.5  218.0  213.5  214.5   0.5   7758
# 2018-07-04   15359295   3324927032  217.0  217.5  215.5  216.0   1.5   5434
# 2018-07-05   18225416   3904832940  214.0  215.0  213.0  214.5  -1.5   5581
# 2018-07-06   31344962   6779063394  217.5  217.5  215.0  217.0   2.5   8620
# 2018-07-09   41165793   9100880393  219.5  223.0  218.5  221.5   4.5  14795
# 2018-07-10   20196957   4498264914  223.0  224.0  222.0  222.0   0.5   6922
# 2018-07-11   19854690   4355547100  220.0  220.0  218.0  220.0  -2.0   7437
# 2018-07-12   23806051   5246628771  218.0  222.0  218.0  220.5   0.5   7885
# 2018-07-13   30419311   6799894334  222.5  224.5  222.5  224.5   4.0  11723
# 2018-07-16   16107254   3612296896  224.5  225.0  223.5  223.5  -1.0   6321
# ...
